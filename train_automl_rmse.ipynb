# %% [markdown]
# # Auto ML

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor
import utils.plot as plot 
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_error, r2_score
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Data Load
#
# ## columns info
#
# |column name|Description|test input|
# |---|---|---|
# |borehole_code|시추공 코드|X|
# |x|위도|O|
# |y|경도|O|
# |depth_start|rockhead 시작 심도|output|
# |Ground name|지반명- 0: 풍화암, 1: 연암, 2: 보통암, 4: 경암|O|
# |Slope|경사|O|
# |Aspect|경사방향|O|
# |DEM|DEM|O|
# |Rock Type|지질도에 따른 rock type|O|
# |dis_bin|radius count에 따라 총 구간을 30개로 나눈 group|X|
#
# * Rock type: {0:화성암, 1:퇴적암, 2:변성암}
# * dis_bin: radius count 그룹에 따라 evaluation 하기 위한 값

# %%
augmented_df = pd.read_csv('data/241210_augmented_250m.csv')
train_df = pd.read_csv('data/241209_Rockhead_Seoul_train(before_aumentation).csv')
test_df = pd.read_csv('data/241209_Rockhead_Seoul_test(before_aumentation).csv')

# %%
augmented_df['rock_type'] = augmented_df['type_num'].astype('category')
augmented_df = augmented_df[['X', 'Y', 'DEM', 'Slope', 'Aspect', 'rock_type', 'R2_weight']]

# one-hot encoding
augmented_df = pd.get_dummies(data=augmented_df, drop_first=True)

# rename
augmented_df.rename(columns={'X': 'x', 'Y':'y', 'Slope': 'slope', 'Aspect':'aspect', 'R2_weight':'depth_start'}, inplace=True)

# drop
train_df = train_df.drop(['neighbors', 'nn_bin', 'rock_type_3.0'], axis=1)
test_df = test_df.drop(['neighbors', 'nn_bin', 'rock_type_3.0'], axis=1)

# column set
augmented_df = augmented_df[train_df.columns]

# %%
augmented_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9693 entries, 0 to 9692
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   x              9693 non-null   float64
#  1   y              9693 non-null   float64
#  2   depth_start    9347 non-null   float64
#  3   slope          9693 non-null   float64
#  4   aspect         9693 non-null   float64
#  5   DEM            9693 non-null   float64
#  6   rock_type_1.0  9693 non-null   bool
#  7   rock_type_2.0  9693 non-null   bool
# dtypes: bool(2), float64(6)
# memory usage: 473.4 KB

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11144 entries, 0 to 11143
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   x              11144 non-null  float64
#  1   y              11144 non-null  float64
#  2   depth_start    11144 non-null  float64
#  3   slope          11144 non-null  float64
#  4   aspect         11144 non-null  float64
#  5   DEM            11144 non-null  float64
#  6   rock_type_1.0  11144 non-null  bool
#  7   rock_type_2.0  11144 non-null  bool
# dtypes: bool(2), float64(6)
# memory usage: 544.3 KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   x              3183 non-null   float64
#  1   y              3183 non-null   float64
#  2   depth_start    3183 non-null   float64
#  3   slope          3183 non-null   float64
#  4   aspect         3183 non-null   float64
#  5   DEM            3183 non-null   float64
#  6   rock_type_1.0  3183 non-null   bool
#  7   rock_type_2.0  3183 non-null   bool
# dtypes: bool(2), float64(6)
# memory usage: 155.5 KB

# %%
train_df_copy = train_df.copy()
augmented_df_copy = augmented_df.copy()
test_df_copy = test_df.copy()

augmented_df_copy['Type'] = 'augmented'
train_df_copy['Type'] = 'train'
test_df_copy['Type'] = 'test'

df_concat = pd.DataFrame(columns=train_df_copy.columns)
df_concat = pd.concat([df_concat, train_df_copy, test_df_copy])

plot.scatter_relation(df_concat, 'x', 'y', 2, 'x, y, type','Type')
# Out:
# C:\Users\mijin\AppData\Local\Temp\ipykernel_27612\1787232671.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df_concat, train_df_copy, test_df_copy])

# %%
train_df = pd.concat[train_df, augmented_df]
train_df.info()
test_df.info()

# %% [markdown]
# ## Pre-Processing

# %%
# Min Max Scaling: x, y, slope, DEM
column_to_scale = ['x', 'y', 'slope', 'aspect', 'DEM']

scaler = MinMaxScaler()

# train_dataset
train_df[column_to_scale] = scaler.fit_transform(train_df[column_to_scale])
train_df['depth_start'] = train_df['depth_start']

# test_dataset
test_df[column_to_scale] = scaler.fit_transform(test_df[column_to_scale])
test_df['depth_start'] = test_df['depth_start']

display(train_df.describe())
display(test_df.describe())
# Out:
#                   x             y   depth_start         slope        aspect  \
# count  16245.000000  16245.000000  16245.000000  16245.000000  16245.000000
# mean       0.534525      0.422278     10.742811      0.523593      0.501207
# std        0.233821      0.187289      7.277804      0.054620      0.290767
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.336490      0.272908      5.000000      0.505552      0.246993
# 50%        0.581727      0.404623      9.900000      0.528247      0.510957
# 75%        0.703134      0.532169     15.600000      0.542125      0.756616
# max        1.000000      1.000000     64.500000      1.000000      1.000000
#
#                 DEM       dis_bin
# count  16245.000000  16245.000000
# mean       0.081943      9.950262
# std        0.074098      5.451414
# min        0.000000      0.000000
# 25%        0.036048      6.000000
# 50%        0.057436      9.000000
# 75%        0.101762     13.000000
# max        1.000000     29.000000
#                  x            y  depth_start        slope       aspect  \
# count  4061.000000  4061.000000  4061.000000  4061.000000  4061.000000
# mean      0.535506     0.413595    10.725260     0.548705     0.505752
# std       0.236515     0.187184     7.116045     0.057255     0.290306
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.333530     0.262296     5.100000     0.531085     0.252633
# 50%       0.584082     0.402635    10.000000     0.553969     0.524646
# 75%       0.707542     0.526315    15.500000     0.568651     0.761617
# max       1.000000     1.000000    56.500000     1.000000     1.000000
#
#                DEM      dis_bin
# count  4061.000000  4061.000000
# mean      0.130934     9.924403
# std       0.113909     5.425669
# min       0.000000     0.000000
# 25%       0.058306     6.000000
# 50%       0.091307     9.000000
# 75%       0.161654    13.000000
# max       1.000000    29.000000

# %%
df_concat = pd.DataFrame(columns=train_df.columns)
df_concat = pd.concat([df_concat, train_df, test_df])
plot.scatter_relation(df_concat, 'x', 'y', 2, 'x, y min-max_scaling check')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18496\2444262702.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df_concat, train_df, test_df])

# %%
train = TabularDataset(train_df.drop(['dis_bin'], axis=1))
test = TabularDataset(test_df.drop(['dis_bin'], axis=1))
X_test = TabularDataset(test_df.drop(['depth_start', 'dis_bin'], axis=1))
y_test = test_df['depth_start'].values.tolist()

# %% [markdown]
# ## Training-Validation

# %%
predictor = TabularPredictor(label='depth_start', 
                             problem_type = 'regression', 
                             eval_metric='r2',
                             verbosity =2 
                             )

predictor.fit(train,
              num_gpus=1,
              time_limit = 3600*24, 
              presets="best_quality", 
              save_space = True, 
              keep_only_best = True,
              save_bag_folds = True,
              ag_args_fit = {'num_gpus': 1} # Train with GPU, # 140 models without gpu, 84 models with gpu during 3600*10(241026), 120 models with gpu during 3600*14(241028)
              )
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20241113_073506"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          16
# Memory Avail:       19.23 GB / 31.93 GB (60.2%)
# Disk Space Avail:   575.02 GB / 931.51 GB (61.7%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 21600s of the 86400s of remaining time (25%).
# 2024-11-13 16:35:08,047	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-13 16:35:15,135	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "AutogluonModels\ag-20241113_073506\ds_sub_fit\sub_fit_ho"
# (_dystack pid=32484) Running DyStack sub-fit ...
# (_dystack pid=32484) Beginning AutoGluon training ... Time limit = 21586s
# (_dystack pid=32484) AutoGluon will save models to "AutogluonModels\ag-20241113_073506\ds_sub_fit\sub_fit_ho"
# (_dystack pid=32484) Train Data Rows:    14440
# (_dystack pid=32484) Train Data Columns: 7
# (_dystack pid=32484) Label Column:       depth_start
# (_dystack pid=32484) Problem Type:       regression
# (_dystack pid=32484) Preprocessing data ...
# (_dystack pid=32484) Using Feature Generators to preprocess the data ...
# (_dystack pid=32484) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=32484) 	Available Memory:                    18766.02 MB
# (_dystack pid=32484) 	Train Data (Original)  Memory Usage: 0.58 MB (0.0% of available memory)
# (_dystack pid=32484) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=32484) 	Stage 1 Generators:
# (_dystack pid=32484) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=32484) 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=32484) 	Stage 2 Generators:
# (_dystack pid=32484) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=32484) 	Stage 3 Generators:
# (_dystack pid=32484) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=32484) 	Stage 4 Generators:
# (_dystack pid=32484) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=32484) 	Stage 5 Generators:
# (_dystack pid=32484) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=32484) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=32484) 		('bool', [])  : 2 | ['rock_type_1', 'rock_type_2']
# (_dystack pid=32484) 		('float', []) : 5 | ['x', 'y', 'slope', 'aspect', 'DEM']
# (_dystack pid=32484) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=32484) 		('float', [])     : 5 | ['x', 'y', 'slope', 'aspect', 'DEM']
# (_dystack pid=32484) 		('int', ['bool']) : 2 | ['rock_type_1', 'rock_type_2']
# (_dystack pid=32484) 	0.1s = Fit runtime
# (_dystack pid=32484) 	7 features in original data used to generate 7 features in processed data.
# (_dystack pid=32484) 	Train Data (Processed) Memory Usage: 0.58 MB (0.0% of available memory)
# (_dystack pid=32484) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=32484) AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# (_dystack pid=32484) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=32484) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=32484) User-specified model hyperparameters to be fit:
# (_dystack pid=32484) {
# (_dystack pid=32484) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=32484) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=32484) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=32484) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=32484) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=32484) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=32484) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=32484) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=32484) }
# (_dystack pid=32484) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=32484) Fitting 108 L1 models ...
# (_dystack pid=32484) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 14387.28s of the 21586.31s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused KNeighborsUnif_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 14376.17s of the 21575.2s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused KNeighborsDist_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 14376.09s of the 21575.12s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: LightGBM_BAG_L1 ... Training model for up to 14376.01s of the 21575.04s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused LightGBM_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 14375.93s of the 21574.96s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused RandomForestMSE_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: CatBoost_BAG_L1 ... Training model for up to 14375.86s of the 21574.89s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused CatBoost_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 14375.78s of the 21574.81s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused ExtraTreesMSE_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 14375.7s of the 21574.73s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: XGBoost_BAG_L1 ... Training model for up to 14375.63s of the 21574.66s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused XGBoost_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 14375.55s of the 21574.58s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 14375.48s of the 21574.51s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484) AssertionError: Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 14375.4s of the 21574.43s of remaining time.
# (_dystack pid=32484) 	Warning: Exception caused CatBoost_r177_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=32484) 		Specified num_gpus per model base is more than the total: 0
# (_dystack pid=32484) Detailed Traceback:
# (_dystack pid=32484) Traceback (most recent call last):
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=32484)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=32484)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=32484)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 848, in fit
# (_dystack pid=32484)     kwargs = self._preprocess_fit_args(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 529, in _preprocess_fit_args
# (_dystack pid=32484)     kwargs = self._preprocess_fit_resources(**kwargs)
# (_dystack pid=32484)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 760, in _preprocess_fit_resources
# (_dystack pid=32484)     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 644, in _calculate_total_resources
# (_dystack pid=32484)     user_specified_lower_level_num_gpus = self._process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble(
# (_dystack pid=32484)                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=32484)   File "d:\rockhead_prediction\.venv\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 590, in _process_user_provided_resource_requirement_to_calculate_total_resource_when_ensemble
# (_dystack pid=32484)     assert user_specified_model_level_resource <= system_resource, f"Specified {resource_type} per model base is more than the total: {system_resource}"
# (_dystack pid=32484)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
# 	44.55s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: XGBoost_r34_BAG_L2 ... Training model for up to 35853.74s of the 35853.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=2.19%)
# 	0.7716	 = Validation score   (r2)
# 	87.27s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_r42_BAG_L2 ... Training model for up to 35763.53s of the 35763.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.97%)
# 	0.7692	 = Validation score   (r2)
# 	128.13s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L2 ... Training model for up to 35632.52s of the 35632.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.24%)
# 	0.7682	 = Validation score   (r2)
# 	224.44s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L2 ... Training model for up to 35405.18s of the 35404.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.25%)
# 	0.7692	 = Validation score   (r2)
# 	233.68s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 5050.45s of the 35167.35s of remaining time.
# 	Ensemble Weights: {'LightGBM_r188_BAG_L2': 0.24, 'NeuralNetFastAI_r95_BAG_L2': 0.24, 'ExtraTrees_r49_BAG_L2': 0.24, 'RandomForest_r39_BAG_L2': 0.16, 'ExtraTreesMSE_BAG_L2': 0.08, 'RandomForest_r15_BAG_L2': 0.04}
# 	0.7784	 = Validation score   (r2)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 51197.81s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 7.8 rows/s (2031 batch size)
# Deleting model WeightedEnsemble_L2. All files under AutogluonModels\ag-20241113_073506\models\WeightedEnsemble_L2 will be removed.
# Deleting model LightGBMXT_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBMXT_BAG_L2 will be removed.
# Deleting model LightGBM_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_BAG_L2 will be removed.
# Deleting model RandomForestMSE_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\RandomForestMSE_BAG_L2 will be removed.
# Deleting model CatBoost_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_BAG_L2 will be removed.
# Deleting model XGBoost_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_BAG_L2 will be removed.
# Deleting model LightGBMLarge_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBMLarge_BAG_L2 will be removed.
# Deleting model CatBoost_r177_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r177_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r79_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r79_BAG_L2 will be removed.
# Deleting model LightGBM_r131_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r131_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r191_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r191_BAG_L2 will be removed.
# Deleting model CatBoost_r9_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r9_BAG_L2 will be removed.
# Deleting model LightGBM_r96_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r96_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r22_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r22_BAG_L2 will be removed.
# Deleting model XGBoost_r33_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r33_BAG_L2 will be removed.
# Deleting model ExtraTrees_r42_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\ExtraTrees_r42_BAG_L2 will be removed.
# Deleting model CatBoost_r137_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r137_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r102_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r102_BAG_L2 will be removed.
# Deleting model CatBoost_r13_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r13_BAG_L2 will be removed.
# Deleting model RandomForest_r195_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\RandomForest_r195_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r145_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r145_BAG_L2 will be removed.
# Deleting model XGBoost_r89_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r89_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r30_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r30_BAG_L2 will be removed.
# Deleting model LightGBM_r130_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r130_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r86_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r86_BAG_L2 will be removed.
# Deleting model CatBoost_r50_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r50_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r11_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r11_BAG_L2 will be removed.
# Deleting model XGBoost_r194_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r194_BAG_L2 will be removed.
# Deleting model ExtraTrees_r172_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\ExtraTrees_r172_BAG_L2 will be removed.
# Deleting model CatBoost_r69_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r69_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r103_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r103_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r14_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r14_BAG_L2 will be removed.
# Deleting model LightGBM_r161_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r161_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r143_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r143_BAG_L2 will be removed.
# Deleting model CatBoost_r70_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r70_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r156_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r156_BAG_L2 will be removed.
# Deleting model LightGBM_r196_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r196_BAG_L2 will be removed.
# Deleting model CatBoost_r167_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r167_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r41_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r41_BAG_L2 will be removed.
# Deleting model XGBoost_r98_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r98_BAG_L2 will be removed.
# Deleting model LightGBM_r15_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r15_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r158_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r158_BAG_L2 will be removed.
# Deleting model CatBoost_r86_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r86_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r37_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r37_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r197_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r197_BAG_L2 will be removed.
# Deleting model CatBoost_r49_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r49_BAG_L2 will be removed.
# Deleting model LightGBM_r143_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r143_BAG_L2 will be removed.
# Deleting model RandomForest_r127_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\RandomForest_r127_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r134_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r134_BAG_L2 will be removed.
# Deleting model RandomForest_r34_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\RandomForest_r34_BAG_L2 will be removed.
# Deleting model LightGBM_r94_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r94_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r143_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r143_BAG_L2 will be removed.
# Deleting model CatBoost_r128_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r128_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r111_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r111_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r31_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r31_BAG_L2 will be removed.
# Deleting model ExtraTrees_r4_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\ExtraTrees_r4_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r65_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r65_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r88_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r88_BAG_L2 will be removed.
# Deleting model LightGBM_r30_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r30_BAG_L2 will be removed.
# Deleting model XGBoost_r49_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r49_BAG_L2 will be removed.
# Deleting model CatBoost_r5_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r5_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r87_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r87_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r71_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r71_BAG_L2 will be removed.
# Deleting model CatBoost_r143_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r143_BAG_L2 will be removed.
# Deleting model ExtraTrees_r178_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\ExtraTrees_r178_BAG_L2 will be removed.
# Deleting model RandomForest_r166_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\RandomForest_r166_BAG_L2 will be removed.
# Deleting model XGBoost_r31_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r31_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r185_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r185_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r160_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r160_BAG_L2 will be removed.
# Deleting model CatBoost_r60_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r60_BAG_L2 will be removed.
# Deleting model LightGBM_r135_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r135_BAG_L2 will be removed.
# Deleting model XGBoost_r22_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r22_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r69_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r69_BAG_L2 will be removed.
# Deleting model CatBoost_r6_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r6_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r138_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r138_BAG_L2 will be removed.
# Deleting model LightGBM_r121_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r121_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r172_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r172_BAG_L2 will be removed.
# Deleting model CatBoost_r180_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r180_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r76_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r76_BAG_L2 will be removed.
# Deleting model ExtraTrees_r197_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\ExtraTrees_r197_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r121_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r121_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r127_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r127_BAG_L2 will be removed.
# Deleting model RandomForest_r16_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\RandomForest_r16_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r194_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r194_BAG_L2 will be removed.
# Deleting model CatBoost_r12_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r12_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r135_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r135_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r4_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r4_BAG_L2 will be removed.
# Deleting model ExtraTrees_r126_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\ExtraTrees_r126_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r36_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r36_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r100_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r100_BAG_L2 will be removed.
# Deleting model CatBoost_r163_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r163_BAG_L2 will be removed.
# Deleting model CatBoost_r198_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\CatBoost_r198_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r187_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetFastAI_r187_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r19_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r19_BAG_L2 will be removed.
# Deleting model XGBoost_r95_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r95_BAG_L2 will be removed.
# Deleting model XGBoost_r34_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\XGBoost_r34_BAG_L2 will be removed.
# Deleting model LightGBM_r42_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\LightGBM_r42_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r1_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r1_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r89_BAG_L2. All files under AutogluonModels\ag-20241113_073506\models\NeuralNetTorch_r89_BAG_L2 will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20241113_073506")

# %%
ld_board = predictor.leaderboard(test, silent=True)

ld_board
# Out:
#                           model  score_test  score_val eval_metric  \
# 0         KNeighborsDist_BAG_L1    0.576036   0.711311          r2
# 1         KNeighborsUnif_BAG_L1    0.571068   0.667409          r2
# 2         ExtraTrees_r49_BAG_L1    0.481314   0.758826          r2
# 3            XGBoost_r98_BAG_L1    0.480137   0.745965          r2
# 4          LightGBM_r121_BAG_L1    0.476933   0.753757          r2
# ..                          ...         ...        ...         ...
# 110  NeuralNetTorch_r185_BAG_L1    0.306093   0.657613          r2
# 111   NeuralNetTorch_r89_BAG_L1    0.305942   0.617243          r2
# 112   NeuralNetTorch_r36_BAG_L1    0.296994   0.546043          r2
# 113   NeuralNetTorch_r22_BAG_L1    0.294602   0.670353          r2
# 114       NeuralNetTorch_BAG_L1    0.289018   0.661395          r2
#
#      pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0          0.094911       0.094518    0.035506                 0.094911
# 1          0.082492       0.074081    0.051518                 0.082492
# 2          2.394392       0.535094    0.888658                 2.394392
# 3          6.427258       1.868768  444.490281                 6.427258
# 4          2.171386       2.555453  842.184119                 2.171386
# ..              ...            ...         ...                      ...
# 110        0.510091       0.095517  529.626082                 0.510091
# 111        0.345175       0.093013  443.878717                 0.345175
# 112        0.282051       0.090013  393.415435                 0.282051
# 113        0.647125       0.081511  490.080850                 0.647125
# 114        0.570817       0.084513  627.756933                 0.570817
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                  0.094518           0.035506            1       True
# 1                  0.074081           0.051518            1       True
# 2                  0.535094           0.888658            1       True
# 3                  1.868768         444.490281            1       True
# 4                  2.555453         842.184119            1       True
# ..                      ...                ...          ...        ...
# 110                0.095517         529.626082            1       True
# 111                0.093013         443.878717            1       True
# 112                0.090013         393.415435            1       True
# 113                0.081511         490.080850            1       True
# 114                0.084513         627.756933            1       True
#
#      fit_order
# 0            2
# 1            1
# 2           54
# 3           47
# 4           85
# ..         ...
# 110         76
# 111        108
# 112         98
# 113         18
# 114         10
#
# [115 rows x 13 columns]

# %% [markdown]
# ## Prediction

# %%
pred_y = predictor.predict(X_test, ld_board.model[1])

# %%
mae = mean_absolute_error(y_test, pred_y)
mse = mean_squared_error(y_test, pred_y)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred_y)

print('mae: ',mae)
print('mse: ',mse)
print('rmse: ',rmse)
print('r2: ',r2) #1에 가까울수록 좋음
# Out:
# mae:  3.335306577629583
# mse:  21.714925220458227
# rmse:  4.659927598199164
# r2:  0.5710684778681563
